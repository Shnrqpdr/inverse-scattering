# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
df_train = pd.read_csv('./dados_train_loss_runs_reduzido.csv')

# %%
df_train.head(5)
# Out:
#       run_1     run_2     run_3     run_4     run_5     run_6
# 0  0.250289  0.476737  0.385498  0.471865  0.486287  0.415065
# 1  0.069642  0.060285  0.020638  0.035179  0.051327  0.023847
# 2  0.051309  0.032178  0.007980  0.004462  0.005177  0.003637
# 3  0.042725  0.022706  0.005583  0.002043  0.002023  0.001526
# 4  0.037512  0.018709  0.004312  0.001381  0.001217  0.000888

# %%
df_cross_val = pd.read_csv('./dados_val_loss_runs_reduzido.csv')

# %%
for run in range(1,7):
    print(run)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6

# %%
fig = plt.figure(figsize=(8,6))
axes = fig.add_axes([0.1,0.1,0.8,0.8])

for run in range(1, 7):
    axes.plot(df_train[f'run_{run}'], ls='-', lw=1.5, label=f'{run} hidden layer')

axes.set_title(f'Loss values of the train data for each hidden layer added')
axes.set_xlabel(f'epochs')
axes.legend(loc='upper right')
plt.grid(linestyle='-', linewidth=0.5)
# plt.savefig('./backups/evaluateModel/01_08/loss_each_hidden_layer_train.png')

# %%
fig = plt.figure(figsize=(8,6))
axes = fig.add_axes([0.1,0.1,0.8,0.8])

for run in range(1, 7):
    axes.plot(df_cross_val[f'run_{run}'], ls='-', lw=1.5, label=f'{run} hidden layer')

axes.set_title(f'Loss values of the cross-validation data for each hidden layer added')
axes.set_xlabel(f'epochs')
axes.legend(loc='upper right')
plt.grid(linestyle='-', linewidth=0.5)
# plt.savefig('./backups/evaluateModel/01_08/loss_each_hidden_layer_val.png')

# %%
last_30_train = df_train.tail(100)

# %%
fig = plt.figure(figsize=(8,6))
axes = fig.add_axes([0.1,0.1,0.8,0.8])

for run in range(1, 7):
    axes.plot(last_30_train[f'run_{run}'], ls='-', lw=1.5, label=f'{run} hidden layer')

axes.set_title(f'Loss values of the train data for each hidden layer added - last 100 epochs')
axes.set_xlabel(f'epochs')
axes.legend(loc='center right')
plt.grid(linestyle='-', linewidth=0.5)
# plt.savefig('./backups/evaluateModel/01_08/loss_each_hidden_layer_last_100_train.png')

# %%
fig = plt.figure(figsize=(8,6))
axes = fig.add_axes([0.1,0.1,0.8,0.8])

for run in range(3, 7):
    axes.plot(last_30_train[f'run_{run}'], ls='-', lw=1.5, label=f'{run} hidden layer')

axes.set_title(f'Loss values of the train data for each hidden layer added - last 100 epochs')
axes.set_xlabel(f'epochs')
axes.legend(loc='upper right')
plt.grid(linestyle='-', linewidth=0.5)
# plt.savefig('./backups/evaluateModel/01_08/loss_3_hidden_layer_last_100_train.png')

# %%
last_30_val = df_cross_val.tail(100)

# %%
fig = plt.figure(figsize=(8,6))
axes = fig.add_axes([0.1,0.1,0.8,0.8])

for run in range(1, 7):
    axes.plot(last_30_val[f'run_{run}'], ls='-', lw=1.5, label=f'{run} hidden layer')

axes.set_title(f'Loss values of the cross-validation data for each hidden layer added - last 100 epochs')
axes.set_xlabel(f'epochs')
axes.legend(loc='upper right')
plt.grid(linestyle='-', linewidth=0.5)
# plt.savefig('./backups/evaluateModel/01_08/loss_each_hidden_layer_last_100_val.png')

# %%
fig = plt.figure(figsize=(8,6))
axes = fig.add_axes([0.1,0.1,0.8,0.8])

for run in range(3, 7):
    axes.plot(last_30_val[f'run_{run}'], ls='-', lw=1.5, label=f'{run} hidden layer')

axes.set_title(f'Loss values of the cross-validation data for each hidden layer added - last 100 epochs')
axes.set_xlabel(f'epochs')
axes.legend(loc='upper right')
plt.grid(linestyle='-', linewidth=0.5)
# plt.savefig('./backups/evaluateModel/01_08/loss_3_hidden_layer_last_100_val.png')
